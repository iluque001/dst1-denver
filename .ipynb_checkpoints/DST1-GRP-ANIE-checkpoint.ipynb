# %%
from pathlib import Path
import pandas as pd
import numpy as np

# %%
column_names = ["date","age_range","industry","job_title","job_context",
                "annual_salary","additional_comp","currency","alt_currency","income_context",
                "country","us_state","city","overall_exp","field_exp","edu_level","gender","race"]
df_salary = pd.read_csv(Path("salary_responses.csv"),skiprows=1,names=column_names)
df_salary
# Out:
#                      date age_range                              industry  \
# 0      4/27/2021 11:02:10     25-34          Education (Higher Education)
# 1      4/27/2021 11:02:22     25-34                     Computing or Tech
# 2      4/27/2021 11:02:38     25-34         Accounting, Banking & Finance
# 3      4/27/2021 11:02:41     25-34                            Nonprofits
# 4      4/27/2021 11:02:42     25-34         Accounting, Banking & Finance
# ...                   ...       ...                                   ...
# 27962    6/8/2023 4:35:52     45-54                           Health care
# 27963   6/15/2023 9:53:13     25-34  Government and Public Administration
# 27964  6/15/2023 11:57:09     25-34                     Computing or Tech
# 27965  6/16/2023 17:58:18     25-34                Business or Consulting
# 27966  6/23/2023 15:44:02     25-34         Accounting, Banking & Finance
#
#                                       job_title              job_context  \
# ...

# %%
df_salary.isnull().sum()
# Out:
# date                   0
# age_range              0
# industry              72
# job_title              0
# job_context        20730
# annual_salary          0
# additional_comp     7263
# currency               0
# alt_currency       27770
# income_context     24932
# country                0
# us_state            4990
# city                  75
# overall_exp            0
# field_exp              0
# edu_level            215
# gender               167
# race                 169
# dtype: int64
